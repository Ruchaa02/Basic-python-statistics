# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("C:/Users/Ruchita/Downloads/Datascience/data_clean.csv")

# %%
df.tail(10)
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 148         149   30.0    193.0   6.9     70     9   26  2010    70       C
# 149         150    NaN    145.0  13.2     77     9   27  2010    77      PS
# 150         151   14.0    191.0  14.3     75     9   28  2010    75       S
# 151         152   18.0    131.0   8.0     76     9   29  2010    76      PS
# 152         153   20.0    223.0  11.5     68     9   30  2010    68       S
# 153         154   41.0    190.0   7.4     67     5    1  2010    67       C
# 154         155   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155         156    NaN    145.0  13.2     77     9   27  2010    77       S
# 156         157   14.0    191.0  14.3     75     9   28  2010    75       S
# 157         158   18.0    131.0   8.0     76     9   29  2010    76       C

# %%
df
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1             2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2             3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3             4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4             5    NaN      NaN  14.3     56     5    5  2010    56       S
# ..          ...    ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4     67     5    1  2010    67       C
# 154         155   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155         156    NaN    145.0  13.2     77     9   27  2010    77       S
# 156         157   14.0    191.0  14.3     75     9   28  2010    75       S
# 157         158   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 10 columns]

# %%
df.shape
# Out:
# (158, 10)

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# Ozone         float64
# Solar.R       float64
# Wind          float64
# Temp C         object
# Month          object
# Day             int64
# Year            int64
# Temp            int64
# Weather        object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  158 non-null    int64
#  1   Ozone       120 non-null    float64
#  2   Solar.R     151 non-null    float64
#  3   Wind        158 non-null    float64
#  4   Temp C      158 non-null    object
#  5   Month       158 non-null    object
#  6   Day         158 non-null    int64
#  7   Year        158 non-null    int64
#  8   Temp        158 non-null    int64
#  9   Weather     155 non-null    object
# dtypes: float64(3), int64(4), object(3)
# memory usage: 12.5+ KB

# %%
df[df.duplicated()].shape
# Out:
# (0, 10)

# %%
df
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1             2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2             3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3             4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4             5    NaN      NaN  14.3     56     5    5  2010    56       S
# ..          ...    ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4     67     5    1  2010    67       C
# 154         155   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155         156    NaN    145.0  13.2     77     9   27  2010    77       S
# 156         157   14.0    191.0  14.3     75     9   28  2010    75       S
# 157         158   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 10 columns]

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Ozone, Solar.R, Wind, Temp C, Month, Day, Year, Temp, Weather]
# Index: []

# %%
df1=df.drop(['Temp C' , 'Month'] , axis=1)

# %%
df1
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4    1  2010    67       S
# 1             2   36.0    118.0   8.0    2  2010    72       C
# 2             3   12.0    149.0  12.6    3  2010    74      PS
# 3             4   18.0    313.0  11.5    4  2010    62       S
# 4             5    NaN      NaN  14.3    5  2010    56       S
# ..          ...    ...      ...   ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4    1  2010    67       C
# 154         155   30.0    193.0   6.9   26  2010    70      PS
# 155         156    NaN    145.0  13.2   27  2010    77       S
# 156         157   14.0    191.0  14.3   28  2010    75       S
# 157         158   18.0    131.0   8.0   29  2010    76       C
#
# [158 rows x 8 columns]

# %%
df2=df1.rename({'Solar.R':'Solar'},axis=1)

# %%
df2
# Out:
#      Unnamed: 0  Ozone  Solar  Wind  Day  Year  Temp Weather
# 0             1   41.0  190.0   7.4    1  2010    67       S
# 1             2   36.0  118.0   8.0    2  2010    72       C
# 2             3   12.0  149.0  12.6    3  2010    74      PS
# 3             4   18.0  313.0  11.5    4  2010    62       S
# 4             5    NaN    NaN  14.3    5  2010    56       S
# ..          ...    ...    ...   ...  ...   ...   ...     ...
# 153         154   41.0  190.0   7.4    1  2010    67       C
# 154         155   30.0  193.0   6.9   26  2010    70      PS
# 155         156    NaN  145.0  13.2   27  2010    77       S
# 156         157   14.0  191.0  14.3   28  2010    75       S
# 157         158   18.0  131.0   8.0   29  2010    76       C
#
# [158 rows x 8 columns]

# %%
df2['Ozone'].hist()
# Out:
# <AxesSubplot:>

# %%
df2.boxplot(column=['Ozone'])
# Out:
# <AxesSubplot:>

# %%
df2['Ozone'].describe()
# Out:
# count    120.000000
# mean      41.583333
# std       32.620709
# min        1.000000
# 25%       18.000000
# 50%       30.500000
# 75%       61.500000
# max      168.000000
# Name: Ozone, dtype: float64

# %%
df2
# Out:
#      Unnamed: 0  Ozone  Solar  Wind  Day  Year  Temp Weather
# 0             1   41.0  190.0   7.4    1  2010    67       S
# 1             2   36.0  118.0   8.0    2  2010    72       C
# 2             3   12.0  149.0  12.6    3  2010    74      PS
# 3             4   18.0  313.0  11.5    4  2010    62       S
# 4             5    NaN    NaN  14.3    5  2010    56       S
# ..          ...    ...    ...   ...  ...   ...   ...     ...
# 153         154   41.0  190.0   7.4    1  2010    67       C
# 154         155   30.0  193.0   6.9   26  2010    70      PS
# 155         156    NaN  145.0  13.2   27  2010    77       S
# 156         157   14.0  191.0  14.3   28  2010    75       S
# 157         158   18.0  131.0   8.0   29  2010    76       C
#
# [158 rows x 8 columns]

# %%
df['Weather'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns
cols=df2.columns
colours=['#000099','#ffff00']
sns.heatmap(df2[cols].isnull(), cmap=sns.color_palette(colours))
# Out:
# <AxesSubplot:>

# %%
df2[df2.isnull().any(axis=1)].head()
# Out:
#     Unnamed: 0  Ozone  Solar  Wind  Day  Year  Temp Weather
# 4            5    NaN    NaN  14.3    5  2010    56       S
# 5            6   28.0    NaN  14.9    6  2010    66       C
# 9           10    NaN  194.0   8.6   10  2010    69       S
# 10          11    7.0    NaN   6.9   11  2010    74       C
# 24          25    NaN   66.0  16.6   25  2010    57      PS

# %%
df2.isnull().sum()
# Out:
# Unnamed: 0     0
# Ozone         38
# Solar          7
# Wind           0
# Day            0
# Year           0
# Temp           0
# Weather        3
# dtype: int64

# %%
mean=df2['Ozone'].mean()
print(mean)
df2['Ozone']=df2['Ozone'].fillna(mean)
# Out:
# 41.583333333333336

# %%
df2
# Out:
#      Unnamed: 0      Ozone  Solar  Wind  Day  Year  Temp Weather
# 0             1  41.000000  190.0   7.4    1  2010    67       S
# 1             2  36.000000  118.0   8.0    2  2010    72       C
# 2             3  12.000000  149.0  12.6    3  2010    74      PS
# 3             4  18.000000  313.0  11.5    4  2010    62       S
# 4             5  41.583333    NaN  14.3    5  2010    56       S
# ..          ...        ...    ...   ...  ...   ...   ...     ...
# 153         154  41.000000  190.0   7.4    1  2010    67       C
# 154         155  30.000000  193.0   6.9   26  2010    70      PS
# 155         156  41.583333  145.0  13.2   27  2010    77       S
# 156         157  14.000000  191.0  14.3   28  2010    75       S
# 157         158  18.000000  131.0   8.0   29  2010    76       C
#
# [158 rows x 8 columns]

# %%
obj_columns=df2[['Weather']]

# %%
obj_columns.isnull().sum()
# Out:
# Weather    3
# dtype: int64

# %%
obj_columns=obj_columns.fillna(obj_columns.mode().iloc[0])

# %%
df2.shape
# Out:
# (158, 8)

# %%
obj_columns.shape
# Out:
# (158, 1)

# %%
df3=pd.concat([df2,obj_columns])
df3
# Out:
#      Unnamed: 0      Ozone  Solar  Wind  Day    Year  Temp Weather
# 0           1.0  41.000000  190.0   7.4  1.0  2010.0  67.0       S
# 1           2.0  36.000000  118.0   8.0  2.0  2010.0  72.0       C
# 2           3.0  12.000000  149.0  12.6  3.0  2010.0  74.0      PS
# 3           4.0  18.000000  313.0  11.5  4.0  2010.0  62.0       S
# 4           5.0  41.583333    NaN  14.3  5.0  2010.0  56.0       S
# ..          ...        ...    ...   ...  ...     ...   ...     ...
# 153         NaN        NaN    NaN   NaN  NaN     NaN   NaN       C
# 154         NaN        NaN    NaN   NaN  NaN     NaN   NaN      PS
# 155         NaN        NaN    NaN   NaN  NaN     NaN   NaN       S
# 156         NaN        NaN    NaN   NaN  NaN     NaN   NaN       S
# 157         NaN        NaN    NaN   NaN  NaN     NaN   NaN       C
#
# [316 rows x 8 columns]

# %%
import seaborn as sns
sns.pairplot(df2)

# %%
df3.corr()
# Out:
#             Unnamed: 0     Ozone     Solar      Wind       Day  Year      Temp
# Unnamed: 0    1.000000  0.111910 -0.109520 -0.158309  0.216219   NaN  0.337537
# Ozone         0.111910  1.000000  0.307253 -0.523806 -0.030241   NaN  0.606275
# Solar        -0.109520  0.307253  1.000000 -0.056594 -0.154212   NaN  0.273322
# Wind         -0.158309 -0.523806 -0.056594  1.000000  0.040151   NaN -0.441247
# Day           0.216219 -0.030241 -0.154212  0.040151  1.000000   NaN -0.124538
# Year               NaN       NaN       NaN       NaN       NaN   NaN       NaN
# Temp          0.337537  0.606275  0.273322 -0.441247 -0.124538   NaN  1.000000

# %%
df3=pd.get_dummies(df1, columns=['Weather'])

# %%
df3
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind  Day  Year  Temp  Weather_C  Weather_PS  \
# 0             1   41.0    190.0   7.4    1  2010    67          0           0
# 1             2   36.0    118.0   8.0    2  2010    72          1           0
# 2             3   12.0    149.0  12.6    3  2010    74          0           1
# 3             4   18.0    313.0  11.5    4  2010    62          0           0
# 4             5    NaN      NaN  14.3    5  2010    56          0           0
# ..          ...    ...      ...   ...  ...   ...   ...        ...         ...
# 153         154   41.0    190.0   7.4    1  2010    67          1           0
# 154         155   30.0    193.0   6.9   26  2010    70          0           1
# 155         156    NaN    145.0  13.2   27  2010    77          0           0
# 156         157   14.0    191.0  14.3   28  2010    75          0           0
# 157         158   18.0    131.0   8.0   29  2010    76          1           0
#
#      Weather_S
# 0            1
# ...

# %%
df3=df3.dropna()

# %%
df3.dtypes
# Out:
# Unnamed: 0      int64
# Ozone         float64
# Solar.R       float64
# Wind          float64
# Day             int64
# Year            int64
# Temp            int64
# Weather_C       uint8
# Weather_PS      uint8
# Weather_S       uint8
# dtype: object

# %%
from numpy import set_printoptions
from sklearn.preprocessing import MinMaxScaler
mscaler=MinMaxScaler().fit_transform(df3)

# %%
x=df3.values

# %%
x
# Out:
# array([[  1.,  41., 190., ...,   0.,   0.,   1.],
#        [  2.,  36., 118., ...,   1.,   0.,   0.],
#        [  3.,  12., 149., ...,   0.,   1.,   0.],
#        ...,
#        [155.,  30., 193., ...,   0.,   1.,   0.],
#        [157.,  14., 191., ...,   0.,   0.,   1.],
#        [158.,  18., 131., ...,   1.,   0.,   0.]])
